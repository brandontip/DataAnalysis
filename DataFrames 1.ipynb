# %%
import pandas as pd

# %%
whr = pd.read_csv("2019WorldHappiness.csv", index_col= "Overall rank")
whr
# Out:
#                      Country or region  Score  GDP per capita  Social support  \
# Overall rank
# 1                              Finland  7.769           1.340           1.587
# 2                              Denmark  7.600           1.383           1.573
# 3                               Norway  7.554           1.488           1.582
# 4                              Iceland  7.494           1.380           1.624
# 5                          Netherlands  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# 152                             Rwanda  3.334           0.359           0.711
# 153                           Tanzania  3.231           0.476           0.885
# 154                        Afghanistan  3.203           0.350           0.517
# 155           Central African Republic  3.083           0.026           0.000
# 156                        South Sudan  2.853           0.306           0.575
#
# ...

# %% [markdown]
# Pandas will convert integers to floats if there is a single NaN in the column.

# %%
whr.dtypes
# Out:
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
whr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 1 to 156
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country or region             156 non-null    object
#  1   Score                         156 non-null    float64
#  2   GDP per capita                156 non-null    float64
#  3   Social support                156 non-null    float64
#  4   Healthy life expectancy       156 non-null    float64
#  5   Freedom to make life choices  156 non-null    float64
#  6   Generosity                    156 non-null    float64
#  7   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 11.0+ KB

# %%
type(whr["Score"])
# Out:
# pandas.core.series.Series

# %%
whr["Score"].value_counts()
# Out:
# 5.208    2
# 5.467    1
# 7.139    1
# 4.944    1
# 4.350    1
#         ..
# 6.028    1
# 5.274    1
# 6.825    1
# 6.300    1
# 6.375    1
# Name: Score, Length: 155, dtype: int64

# %%
whr.dropna(subset=['Score'])
# Out:
#                      Country or region  Score  GDP per capita  Social support  \
# Overall rank
# 1                              Finland  7.769           1.340           1.587
# 2                              Denmark  7.600           1.383           1.573
# 3                               Norway  7.554           1.488           1.582
# 4                              Iceland  7.494           1.380           1.624
# 5                          Netherlands  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# 152                             Rwanda  3.334           0.359           0.711
# 153                           Tanzania  3.231           0.476           0.885
# 154                        Afghanistan  3.203           0.350           0.517
# 155           Central African Republic  3.083           0.026           0.000
# 156                        South Sudan  2.853           0.306           0.575
#
# ...

# %% [markdown]
# Use .astype("category") when dealing with a column that has a lot of repitition

# %%
whr.sort_values("Healthy life expectancy" , ascending=False)
# you can sort by multiple columns using a list, and ascending can be passed a listvalkues
# Out:
#                      Country or region  Score  GDP per capita  Social support  \
# Overall rank
# 34                           Singapore  6.262           1.572           1.463
# 76                           Hong Kong  5.430           1.438           1.277
# 58                               Japan  5.886           1.327           1.419
# 30                               Spain  6.354           1.286           1.484
# 6                          Switzerland  7.480           1.452           1.526
# ...                                ...    ...             ...             ...
# 99                         Ivory Coast  4.944           0.569           0.808
# 132                               Chad  4.350           0.350           0.766
# 144                            Lesotho  3.802           0.489           1.169
# 155           Central African Republic  3.083           0.026           0.000
# 135                          Swaziland  4.212           0.811           1.149
#
# ...

# %%
whr.sort_index()
# Out:
#                      Country or region  Score  GDP per capita  Social support  \
# Overall rank
# 1                              Finland  7.769           1.340           1.587
# 2                              Denmark  7.600           1.383           1.573
# 3                               Norway  7.554           1.488           1.582
# 4                              Iceland  7.494           1.380           1.624
# 5                          Netherlands  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# 152                             Rwanda  3.334           0.359           0.711
# 153                           Tanzania  3.231           0.476           0.885
# 154                        Afghanistan  3.203           0.350           0.517
# 155           Central African Republic  3.083           0.026           0.000
# 156                        South Sudan  2.853           0.306           0.575
#
# ...

# %%
whr["Social support"].rank(ascending=False).astype("int")
# Out:
# Overall rank
# 1        2
# 2        4
# 3        3
# 4        1
# 5       15
#       ...
# 152    145
# 153    132
# 154    152
# 155    156
# 156    149
# Name: Social support, Length: 156, dtype: int32
